# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/68501079-0695df00-023c-11ea-841f-455dac84a089.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Reading HTML tables
#
# In this lecture we'll learn how to read and parse HTML tables from websites into a list of `DataFrame` objects to work with.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (5.3.1)

# %%
import pandas as pd

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Parsing raw HTML strings
#
# Another useful pandas method is `read_html()`. This method will read HTML tables from a given URL, a file-like object, or a raw string containing HTML, and return a list of `DataFrame` objects.
#
# Let's try to read the following `html_string` into a `DataFrame`.

# %%
html_string = """
<table>
    <thead>
      <tr>
        <th>Order date</th>
        <th>Region</th>
        <th>Item</th>
        <th>Units</th>
        <th>Unit cost</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td>1/6/2018</td>
        <td>East</td>
        <td>Pencil</td>
        <td>95</td>
        <td>1.99</td>
      </tr>
      <tr>
        <td>1/23/2018</td>
        <td>Central</td>
        <td>Binder</td>
        <td>50</td>
        <td>19.99</td>
      </tr>
      <tr>
        <td>2/9/2018</td>
        <td>Central</td>
        <td>Pencil</td>
        <td>36</td>
        <td>4.99</td>
      </tr>
      <tr>
        <td>3/15/2018</td>
        <td>West</td>
        <td>Pen</td>
        <td>27</td>
        <td>19.99</td>
      </tr>
    </tbody>
</table>
"""

# %%
dfs = pd.read_html(html_string) # Para evaluar que no existan datos ocultos en la página.
# Out:
# <ipython-input-4-bb5fd531bf31>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(html_string)

# %% [markdown]
# The `read_html` just returned one `DataFrame` object:

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]

df
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# Previous `DataFrame` looks quite similar to the raw HTML table, but now we have a `DataFrame` object, so we can apply any pandas operation we want to it.

# %%
df.shape
# Out:
# (4, 5)

# %%
df.loc[df['Region'] == 'Central']
# Out:
#   Order date   Region    Item  Units  Unit cost
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %%
df.loc[df['Units'] > 35]
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %% [markdown]
# ### Defining header
#
# Pandas will automatically find the header to use thanks to the <thead> tag.
#
# But in many cases we'll find wrong or incomplete tables that make the `read_html` method parse the tables in a wrong way without the proper headers.
#
# To fix them we can use the `header` parameter.

# %%
html_string = """
<table>
  <tr>
    <td>Order date</td>
    <td>Region</td>
    <td>Item</td>
    <td>Units</td>
    <td>Unit cost</td>
  </tr>
  <tr>
    <td>1/6/2018</td>
    <td>East</td>
    <td>Pencil</td>
    <td>95</td>
    <td>1.99</td>
  </tr>
  <tr>
    <td>1/23/2018</td>
    <td>Central</td>
    <td>Binder</td>
    <td>50</td>
    <td>19.99</td>
  </tr>
  <tr>
    <td>2/9/2018</td>
    <td>Central</td>
    <td>Pencil</td>
    <td>36</td>
    <td>4.99</td>
  </tr>
  <tr>
    <td>3/15/2018</td>
    <td>West</td>
    <td>Pen</td>
    <td>27</td>
    <td>19.99</td>
  </tr>
</table>
"""

# %%
pd.read_html(html_string)[0]
# Out:
# <ipython-input-13-63684c670060>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(html_string)[0]
#             0        1       2      3          4
# 0  Order date   Region    Item  Units  Unit cost
# 1    1/6/2018     East  Pencil     95       1.99
# 2   1/23/2018  Central  Binder     50      19.99
# 3    2/9/2018  Central  Pencil     36       4.99
# 4   3/15/2018     West     Pen     27      19.99

# %% [markdown]
# In this case, we'll need to pass the row number to use as header using the `header` parameter.

# %%
pd.read_html(html_string, header=0)[0]
# Out:
# <ipython-input-14-b64e381ec9c5>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(html_string, header=0)[0]
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Parsing HTML tables from the web
#
# Now that we know how `read_html` works, go one step beyond and try to parse HTML tables directly from an URL.
#
# To do that we'll call the `read_html` method with an URL as paramter.

# %% [markdown]
# ### Simple example

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# %%
nba_tables = pd.read_html(html_url)

# %%
len(nba_tables)
# Out:
# 2

# %% [markdown]
# We'll work with the only one table found:

# %%
nba = nba_tables[0]

# %%
nba.head()
# Out:
#     Rk                 Player   Age Team Pos     G    GS    MP    FG   FGA  \
# 0  1.0           James Harden  29.0  HOU  PG  78.0  78.0  36.8  10.8  24.5
# 1  2.0            Paul George  28.0  OKC  SF  77.0  77.0  36.9   9.2  21.0
# 2  3.0  Giannis Antetokounmpo  24.0  MIL  PF  72.0  72.0  32.8  10.0  17.3
# 3  4.0            Joel Embiid  24.0  PHI   C  64.0  64.0  33.7   9.1  18.7
# 4  5.0           LeBron James  34.0  LAL  SF  55.0  55.0  35.2  10.1  19.9
#
#    ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS                Awards
# 0  ...  0.8   5.8   6.6  7.5  2.0  0.7  5.0  3.1  36.1         MVP-2,AS,NBA1
# 1  ...  1.4   6.8   8.2  4.1  2.2  0.4  2.7  2.8  28.0  MVP-3,DPOY-3,AS,NBA1
# 2  ...  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7  MVP-1,DPOY-2,AS,NBA1
# 3  ...  2.5  11.1  13.6  3.7  0.7  1.9  3.5  3.3  27.5  MVP-7,DPOY-4,AS,NBA2
# 4  ...  1.0   7.4   8.5  8.3  1.3  0.6  3.6  1.7  27.4        MVP-11,AS,NBA3
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Complex example
#
# We can also use the `requests` module to get HTML code from an URL to parse it into `DataFrame` objects.
#
# If we look at the given URL we can see multiple tables about The Simpsons TV show.
#
# We want to keep the table with information about each season.

# %%
import requests

html_url = "https://en.wikipedia.org/wiki/The_Simpsons"

# %%
r = requests.get(html_url)

wiki_tables = pd.read_html(r.text, header=0)
# Out:
# <ipython-input-67-974494d9a0bd>:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   wiki_tables = pd.read_html(r.text, header=0)

# %%
len(wiki_tables) # Cantidad de tablas en el url.
# Out:
# 49

# %%
simpsons = wiki_tables[2]

# %%
simpsons.head()
# Out:
#    Season Season.1  No. of episodes    Originally aired Originally aired.1  \
# 0  Season   Season  No. of episodes     Season premiere      Season finale
# 1  Season   Season  No. of episodes     Season premiere      Season finale
# 2       1  1989–90               13   December 17, 1989       May 13, 1990
# 3       2  1990–91               22    October 11, 1990      July 11, 1991
# 4       3  1991–92               24  September 19, 1991    August 27, 1992
#
#   Originally aired.2                  Viewership          Viewership.1  \
# 0     Time slot (ET)  Avg. viewers (in millions)  Most watched episode
# 1     Time slot (ET)  Avg. viewers (in millions)    Viewers (millions)
# 2     Sunday 8:30 pm                        27.8             33.5[174]
# 3   Thursday 8:00 pm                        24.4             33.6[175]
# 4   Thursday 8:00 pm                        21.8             25.5[176]
#
#               Viewership.2
# 0     Most watched episode
# 1            Episode title
# 2  "Life on the Fast Lane"
# 3       "Bart Gets an 'F'"
# 4          "Colonel Homer"

# %%
simpsons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Season              38 non-null     object
#  1   Season.1            38 non-null     object
#  2   No. of episodes     38 non-null     object
#  3   Originally aired    38 non-null     object
#  4   Originally aired.1  38 non-null     object
#  5   Originally aired.2  38 non-null     object
#  6   Viewership          38 non-null     object
#  7   Viewership.1        38 non-null     object
#  8   Viewership.2        38 non-null     object
# dtypes: object(9)
# memory usage: 2.8+ KB

# %% [markdown]
# Quick clean on the table: remove extra header rows and set `Season` as index.

# %%
simpsons.drop([0, 1], inplace=True) # Elimina las primeras dos filas.

# %%
simpsons.set_index('Season', inplace=True)

# %%
simpsons
# Out:
#          Season.1 No. of episodes    Originally aired Originally aired.1  \
# Season
# 1         1989–90              13   December 17, 1989       May 13, 1990
# 2         1990–91              22    October 11, 1990      July 11, 1991
# 3         1991–92              24  September 19, 1991    August 27, 1992
# 4         1992–93              22  September 24, 1992       May 13, 1993
# 5         1993–94              22  September 30, 1993       May 19, 1994
# 6         1994–95              25   September 4, 1994       May 21, 1995
# 7         1995–96              25  September 17, 1995       May 19, 1996
# 8         1996–97              25    October 27, 1996       May 18, 1997
# 9         1997–98              25  September 21, 1997       May 17, 1998
# 10        1998–99              23     August 23, 1998       May 16, 1999
# 11      1999–2000              22  September 26, 1999       May 21, 2000
# 12        2000–01              21    November 1, 2000       May 20, 2001
# 13        2001–02              22    November 6, 2001       May 22, 2002
# 14        2002–03              22    November 3, 2002       May 18, 2003
# 15        2003–04              22    November 2, 2003       May 23, 2004
# 16        2004–05              21    November 7, 2004       May 15, 2005
# 17        2005–06              22  September 11, 2005       May 21, 2006
# 18        2006–07              22  September 10, 2006       May 20, 2007
# 19        2007–08              20  September 23, 2007       May 18, 2008
# 20        2008–09              21  September 28, 2008       May 17, 2009
# 21        2009–10              23  September 27, 2009       May 23, 2010
# 22        2010–11              22  September 26, 2010       May 22, 2011
# 23        2011–12              22  September 25, 2011       May 20, 2012
# 24        2012–13              22  September 30, 2012       May 19, 2013
# 25        2013–14              22  September 29, 2013       May 18, 2014
# 26        2014–15              22  September 28, 2014       May 17, 2015
# 27        2015–16              22  September 27, 2015       May 22, 2016
# 28        2016–17              22  September 25, 2016       May 21, 2017
# 29        2017–18              21     October 1, 2017       May 20, 2018
# 30        2018–19              23  September 30, 2018       May 12, 2019
# 31        2019–20              22  September 29, 2019       May 17, 2020
# 32        2020–21              22  September 27, 2020       May 23, 2021
# 33        2021–22              22  September 26, 2021       May 22, 2022
# 34        2022–23              22  September 25, 2022       May 21, 2023
# 35        2023–24              18     October 1, 2023       May 19, 2024
# 36        2024–25             TBA  September 29, 2024                TBA
#
#                                        Originally aired.2 Viewership  \
# Season
# 1                                          Sunday 8:30 pm       27.8
# 2                                        Thursday 8:00 pm       24.4
# 3                                        Thursday 8:00 pm       21.8
# 4                                        Thursday 8:00 pm       22.4
# 5                                        Thursday 8:00 pm       18.9
# 6                                          Sunday 8:00 pm       15.6
# 7       Sunday 8:00 pm (Episodes 1–24) Sunday 8:30 pm ...       15.1
# 8       Sunday 8:30 pm (Episodes 1–3) Sunday 8:00 pm (...       14.5
# 9                                          Sunday 8:00 pm       15.3
# 10                                         Sunday 8:00 pm       13.5
# 11                                         Sunday 8:00 pm        8.8
# 12                                         Sunday 8:00 pm       15.5
# 13      Tuesday 8:30 pm (Episode 1) Sunday 8:00 pm (Ep...       12.5
# 14      Sunday 8:00 pm (Episodes 1–11, 13–21) Sunday 8...       14.4
# 15                                         Sunday 8:00 pm       11.0
# 16      Sunday 8:00 pm (Episodes 1–7, 9–16, 18, 20) Su...       10.2
# 17                                         Sunday 8:00 pm       9.55
# 18                                         Sunday 8:00 pm       9.15
# 19                                         Sunday 8:00 pm       8.37
# 20      Sunday 8:00 pm (Episodes 1–7, 9–21) Sunday 8:3...        7.1
# 21                                         Sunday 8:00 pm        7.1
# 22                                         Sunday 8:00 pm       7.09
# 23                                         Sunday 8:00 pm  6.15[197]
# 24      Sunday 8:00 pm (Episodes 1–21) Sunday 8:30 pm ...  5.41[199]
# 25      Sunday 8:00 pm (Episodes 1–11, 13–22) Sunday 7...  5.02[201]
# 26                                         Sunday 8:00 pm  5.61[203]
# 27                                         Sunday 8:00 pm   4.0[205]
# 28                                         Sunday 8:00 pm  4.80[207]
# 29                                         Sunday 8:00 pm  4.07[209]
# 30                                         Sunday 8:00 pm  3.10[211]
# 31                                         Sunday 8:00 pm  2.58[213]
# 32      Sunday 8:00 pm (Episodes 1–10, 12–22) Sunday 9...  2.32[215]
# 33      Sunday 8:00 pm (Episodes 1–10, 12–22) Sunday 9...  2.25[217]
# 34      Sunday 8:00 pm (Episodes 1–8, 10–22) Sunday 8:...  1.83[219]
# 35      Sunday 8:00 pm (Episodes 1–5, 7, 10–18) Sunday...  1.99[221]
# 36                                         Sunday 8:00 pm        TBA
#
#        Viewership.1                                  Viewership.2
# Season
# 1         33.5[174]                       "Life on the Fast Lane"
# 2         33.6[175]                            "Bart Gets an 'F'"
# 3         25.5[176]                               "Colonel Homer"
# 4         28.6[177]                           "Lisa's First Word"
# 5         24.0[178]                      "Treehouse of Horror IV"
# 6         22.2[179]                       "Treehouse of Horror V"
# 7         22.6[180]               "Who Shot Mr. Burns? – Part II"
# 8        20.41[182]                       "The Springfield Files"
# 9        19.80[183]            "The Two Mrs. Nahasapeemapetilons"
# 10       19.11[184]                       "Sunday, Cruddy Sunday"
# 11       19.16[185]                                   "Faith Off"
# 12       18.52[186]                                        "HOMR"
# 13       14.91[187]                              "The Parent Rap"
# 14       22.04[188]               "I'm Spelling as Fast as I Can"
# 15       16.30[189]                      "I, (Annoyed Grunt)-Bot"
# 16       23.07[190]              "Homer and Ned's Hail Mary Pass"
# 17       11.66[191]                     "Treehouse of Horror XVI"
# 18       11.63[192]  "The Mook, the Chef, the Wife and Her Homer"
# 19       11.74[193]                   "Treehouse of Horror XVIII"
# 20       12.40[194]                     "Treehouse of Horror XIX"
# 21       14.62[195]             "Once Upon a Time in Springfield"
# 22       12.55[196]                     "Moms I'd Like to Forget"
# 23       11.48[198]                       "The D'oh-cial Network"
# 24        8.97[200]                   "Homer Goes to Prep School"
# 25       12.04[202]                          "Steal This Episode"
# 26       10.62[204]               "The Man Who Came to Be Dinner"
# 27        8.33[206]          "Teenage Mutant Milk-Caused Hurdles"
# 28        8.19[208]                              "Pork and Burns"
# 29        8.04[210]                            "Frink Gets Testy"
# 30        8.20[212]                         "The Girl on the Bus"
# 31        5.63[214]                          "Go Big or Go Homer"
# 32        4.93[216]                    "Treehouse of Horror XXXI"
# 33        3.97[218]                "Portrait of a Lackey on Fire"
# 34        4.77[220]                      "From Beer to Paternity"
# 35        5.41[222]                          "Do the Wrong Thing"
# 36              TBA                                           TBA

# %% [markdown]
# Which season has the lowest number of episodes?

# %%
simpsons['No. of episodes'].unique()
# Out:
# array(['13', '22', '24', '25', '23', '21', '20', '18'], dtype=object)

# %%
simpsons = simpsons.loc[simpsons['No. of episodes'] != 'TBA']

# %%
min_season = simpsons['No. of episodes'].min()

min_season
# Out:
# '13'

# %%
simpsons.loc[simpsons['No. of episodes'] == min_season]
# Out:
#        Season.1 No. of episodes   Originally aired Originally aired.1  \
# Season
# 1       1989–90              13  December 17, 1989       May 13, 1990
#
#        Originally aired.2 Viewership Viewership.1             Viewership.2
# Season
# 1          Sunday 8:30 pm       27.8    33.5[174]  "Life on the Fast Lane"

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Save to CSV file
#
# Finally save the `DataFrame` to a CSV file as we saw on previous lectures.

# %%
simpsons.head()
# Out:
#        Season.1 No. of episodes    Originally aired Originally aired.1  \
# Season
# 1       1989–90              13   December 17, 1989       May 13, 1990
# 2       1990–91              22    October 11, 1990      July 11, 1991
# 3       1991–92              24  September 19, 1991    August 27, 1992
# 4       1992–93              22  September 24, 1992       May 13, 1993
# 5       1993–94              22  September 30, 1993       May 19, 1994
#
#        Originally aired.2 Viewership Viewership.1              Viewership.2
# Season
# 1          Sunday 8:30 pm       27.8    33.5[174]   "Life on the Fast Lane"
# 2        Thursday 8:00 pm       24.4    33.6[175]        "Bart Gets an 'F'"
# 3        Thursday 8:00 pm       21.8    25.5[176]           "Colonel Homer"
# 4        Thursday 8:00 pm       22.4    28.6[177]       "Lisa's First Word"
# 5        Thursday 8:00 pm       18.9    24.0[178]  "Treehouse of Horror IV"

# %%
simpsons.to_csv('Simpsons_out.csv')

# %%
pd.read_csv('Simpsons_out.csv', index_col='Season').head()
# Out:
#        Season.1  No. of episodes    Originally aired Originally aired.1  \
# Season
# 1       1989–90               13   December 17, 1989       May 13, 1990
# 2       1990–91               22    October 11, 1990      July 11, 1991
# 3       1991–92               24  September 19, 1991    August 27, 1992
# 4       1992–93               22  September 24, 1992       May 13, 1993
# 5       1993–94               22  September 30, 1993       May 19, 1994
#
#        Originally aired.2 Viewership Viewership.1              Viewership.2
# Season
# 1          Sunday 8:30 pm       27.8    33.5[174]   "Life on the Fast Lane"
# 2        Thursday 8:00 pm       24.4    33.6[175]        "Bart Gets an 'F'"
# 3        Thursday 8:00 pm       21.8    25.5[176]           "Colonel Homer"
# 4        Thursday 8:00 pm       22.4    28.6[177]       "Lisa's First Word"
# 5        Thursday 8:00 pm       18.9    24.0[178]  "Treehouse of Horror IV"

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
